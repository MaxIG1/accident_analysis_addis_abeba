# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import pandas as pd
import numpy as np

# %%
# Path settings csv file
csv_filepath = '../data/interim/gower_imputed.csv'

# Loading the csv file
data_gower = pd.read_csv(csv_filepath)
print("Data loaded successfully")
# Out:
# Data loaded successfully

# %%
start = 0.1
end = 0.32
step = 0.02
eps_values = np.arange(start, end, step)
start = 0
end = 140
step = 20
min_samples = np.arange(start, end, step)

total_combinations = len(eps_values[1:]) * len(min_samples[1:])
total_combinations
# Out:
# 60

# %% [markdown]
# # Clustering the imputed data

# %%
df_analysis_gower = pd.DataFrame(columns=["eps_value", "min_sample", "score", "n_clusters", "cluster_types"])

current_combination = 0

for eps_value in eps_values[1:]:
    for min_sample in min_samples[1:]:
        current_combination += 1
        print(f"Processing combination {current_combination}/{total_combinations} (eps_value={eps_value}, min_sample={min_sample})")

        # Perform DBSCAN clustering
        dbscan_cluster = DBSCAN(eps=eps_value, min_samples=min_sample, metric="precomputed", n_jobs=-1)
        labels = dbscan_cluster.fit_predict(data_gower)
        n_clusters = len(set(labels))
        cluster_types = set(labels)
        try:
            score = silhouette_score(data_gower, labels)
        except ValueError:
            score = 0
        new_row = {'eps_value': eps_value, 'min_sample': min_sample, 'score': score, 'n_clusters': n_clusters,
                   'cluster_types': cluster_types}

        # Adding the new row without using append
        df_analysis_gower.loc[len(df_analysis_gower)] = new_row
# Out:
# Processing combination 1/60 (eps_value=0.12000000000000001, min_sample=20)
# Processing combination 2/60 (eps_value=0.12000000000000001, min_sample=40)
# Processing combination 3/60 (eps_value=0.12000000000000001, min_sample=60)
# Processing combination 4/60 (eps_value=0.12000000000000001, min_sample=80)
# Processing combination 5/60 (eps_value=0.12000000000000001, min_sample=100)
# Processing combination 6/60 (eps_value=0.12000000000000001, min_sample=120)
# Processing combination 7/60 (eps_value=0.14, min_sample=20)
# Processing combination 8/60 (eps_value=0.14, min_sample=40)
# Processing combination 9/60 (eps_value=0.14, min_sample=60)
# Processing combination 10/60 (eps_value=0.14, min_sample=80)
# Processing combination 11/60 (eps_value=0.14, min_sample=100)
# Processing combination 12/60 (eps_value=0.14, min_sample=120)
# Processing combination 13/60 (eps_value=0.16000000000000003, min_sample=20)
# Processing combination 14/60 (eps_value=0.16000000000000003, min_sample=40)
# Processing combination 15/60 (eps_value=0.16000000000000003, min_sample=60)
# Processing combination 16/60 (eps_value=0.16000000000000003, min_sample=80)
# Processing combination 17/60 (eps_value=0.16000000000000003, min_sample=100)
# Processing combination 18/60 (eps_value=0.16000000000000003, min_sample=120)
# Processing combination 19/60 (eps_value=0.18000000000000002, min_sample=20)
# Processing combination 20/60 (eps_value=0.18000000000000002, min_sample=40)
# Processing combination 21/60 (eps_value=0.18000000000000002, min_sample=60)
# Processing combination 22/60 (eps_value=0.18000000000000002, min_sample=80)
# Processing combination 23/60 (eps_value=0.18000000000000002, min_sample=100)
# Processing combination 24/60 (eps_value=0.18000000000000002, min_sample=120)
# Processing combination 25/60 (eps_value=0.2, min_sample=20)
# Processing combination 26/60 (eps_value=0.2, min_sample=40)
# Processing combination 27/60 (eps_value=0.2, min_sample=60)
# Processing combination 28/60 (eps_value=0.2, min_sample=80)
# Processing combination 29/60 (eps_value=0.2, min_sample=100)
# Processing combination 30/60 (eps_value=0.2, min_sample=120)
# Processing combination 31/60 (eps_value=0.22000000000000003, min_sample=20)
# Processing combination 32/60 (eps_value=0.22000000000000003, min_sample=40)
# Processing combination 33/60 (eps_value=0.22000000000000003, min_sample=60)
# Processing combination 34/60 (eps_value=0.22000000000000003, min_sample=80)
# Processing combination 35/60 (eps_value=0.22000000000000003, min_sample=100)
# Processing combination 36/60 (eps_value=0.22000000000000003, min_sample=120)
# Processing combination 37/60 (eps_value=0.24000000000000002, min_sample=20)
# Processing combination 38/60 (eps_value=0.24000000000000002, min_sample=40)
# Processing combination 39/60 (eps_value=0.24000000000000002, min_sample=60)
# Processing combination 40/60 (eps_value=0.24000000000000002, min_sample=80)
# Processing combination 41/60 (eps_value=0.24000000000000002, min_sample=100)
# Processing combination 42/60 (eps_value=0.24000000000000002, min_sample=120)
# Processing combination 43/60 (eps_value=0.26, min_sample=20)
# Processing combination 44/60 (eps_value=0.26, min_sample=40)
# Processing combination 45/60 (eps_value=0.26, min_sample=60)
# Processing combination 46/60 (eps_value=0.26, min_sample=80)
# Processing combination 47/60 (eps_value=0.26, min_sample=100)
# Processing combination 48/60 (eps_value=0.26, min_sample=120)
# Processing combination 49/60 (eps_value=0.28, min_sample=20)
# Processing combination 50/60 (eps_value=0.28, min_sample=40)
# Processing combination 51/60 (eps_value=0.28, min_sample=60)
# Processing combination 52/60 (eps_value=0.28, min_sample=80)
# Processing combination 53/60 (eps_value=0.28, min_sample=100)
# Processing combination 54/60 (eps_value=0.28, min_sample=120)

# %%
df_analysis_gower.sort_values(by="score", ascending=False)
# Out:
#     eps_value  min_sample     score  n_clusters        cluster_types
# 81       0.20          20  0.323211           2              {0, -1}
# 82       0.20          40  0.319070           2              {0, -1}
# 83       0.20          60  0.315165           2              {0, -1}
# 84       0.20          80  0.310424           2              {0, -1}
# 85       0.20         100  0.308021           2              {0, -1}
# ..        ...         ...       ...         ...                  ...
# 26       0.06         180  0.000000           1                 {-1}
# 34       0.08         160  0.000000           1                 {-1}
# 35       0.08         180  0.000000           1                 {-1}
# 0        0.02          20  0.000000           1                 {-1}
# 18       0.06          20 -0.027694           6  {0, 1, 2, 3, 4, -1}
#
# [90 rows x 5 columns]

# %% [markdown]
# # Clustering the data, where the NaN where dropped

# %%
# Path settings csv file
csv_filepath = '../data/interim/gower_no_nan.csv'

# Loading the csv file
data_gower_no_nan = pd.read_csv(csv_filepath)
print("Data loaded successfully")
# Out:
# Data loaded successfully

# %%
df_analysis_gower_no_nan = pd.DataFrame(columns=["eps_value", "min_sample", "score", "n_clusters", "cluster_types"])

current_combination = 0

for eps_value in eps_values[1:]:
    for min_sample in min_samples[1:]:
        current_combination += 1
        print(f"Processing combination {current_combination}/{total_combinations} (eps_value={eps_value}, min_sample={min_sample})")

        # Perform DBSCAN clustering
        dbscan_cluster = DBSCAN(eps=eps_value, min_samples=min_sample, metric="precomputed", n_jobs=-1)
        labels = dbscan_cluster.fit_predict(data_gower_no_nan)
        n_clusters = len(set(labels))
        cluster_types = set(labels)
        try:
            score = silhouette_score(data_gower_no_nan, labels)
            print(score)
        except ValueError:
            score = 0
        new_row = {'eps_value': eps_value, 'min_sample': min_sample, 'score': score, 'n_clusters': n_clusters,
                   'cluster_types': cluster_types}

        # Adding the new row without using append
        df_analysis_gower_no_nan.loc[len(df_analysis_gower_no_nan)] = new_row
# Out:
# Processing combination 1/60 (eps_value=0.12000000000000001, min_sample=20)
# 0.17192738661847665
# Processing combination 2/60 (eps_value=0.12000000000000001, min_sample=40)
# 0.1554297069956887
# Processing combination 3/60 (eps_value=0.12000000000000001, min_sample=60)
# 0.13568154173426306
# Processing combination 4/60 (eps_value=0.12000000000000001, min_sample=80)
# 0.10948730618062436
# Processing combination 5/60 (eps_value=0.12000000000000001, min_sample=100)
# 0.08165184169311451
# Processing combination 6/60 (eps_value=0.12000000000000001, min_sample=120)
# 0.052922357650790425
# Processing combination 7/60 (eps_value=0.14, min_sample=20)
# 0.20821476007698062
# Processing combination 8/60 (eps_value=0.14, min_sample=40)
# 0.20084377228365866
# Processing combination 9/60 (eps_value=0.14, min_sample=60)
# 0.19483289920926972
# Processing combination 10/60 (eps_value=0.14, min_sample=80)
# 0.18908380689993312
# Processing combination 11/60 (eps_value=0.14, min_sample=100)
# 0.1835626265914732
# Processing combination 12/60 (eps_value=0.14, min_sample=120)
# 0.17807840686678245
# Processing combination 13/60 (eps_value=0.16000000000000003, min_sample=20)
# 0.23624773322837697
# Processing combination 14/60 (eps_value=0.16000000000000003, min_sample=40)
# 0.23020403008729648
# Processing combination 15/60 (eps_value=0.16000000000000003, min_sample=60)
# 0.2242857220972129
# Processing combination 16/60 (eps_value=0.16000000000000003, min_sample=80)
# 0.22040934930068531
# Processing combination 17/60 (eps_value=0.16000000000000003, min_sample=100)
# 0.21625887623728557
# Processing combination 18/60 (eps_value=0.16000000000000003, min_sample=120)
# 0.21274201526566047
# Processing combination 19/60 (eps_value=0.18000000000000002, min_sample=20)
# 0.25225846427093707
# Processing combination 20/60 (eps_value=0.18000000000000002, min_sample=40)
# 0.2480089764055231
# Processing combination 21/60 (eps_value=0.18000000000000002, min_sample=60)
# 0.24335531889866654
# Processing combination 22/60 (eps_value=0.18000000000000002, min_sample=80)
# 0.23883338011036462
# Processing combination 23/60 (eps_value=0.18000000000000002, min_sample=100)
# 0.23467402342144283
# Processing combination 24/60 (eps_value=0.18000000000000002, min_sample=120)
# 0.2296640461889495
# Processing combination 25/60 (eps_value=0.2, min_sample=20)
# 0.2963836624548247
# Processing combination 26/60 (eps_value=0.2, min_sample=40)
# 0.2911535429174369
# Processing combination 27/60 (eps_value=0.2, min_sample=60)
# 0.2864419487355136
# Processing combination 28/60 (eps_value=0.2, min_sample=80)
# 0.2820986745530771
# Processing combination 29/60 (eps_value=0.2, min_sample=100)
# 0.2801675774897308
# Processing combination 30/60 (eps_value=0.2, min_sample=120)
# 0.2765294802906203
# Processing combination 31/60 (eps_value=0.22000000000000003, min_sample=20)
# 0.31264141906211285
# Processing combination 32/60 (eps_value=0.22000000000000003, min_sample=40)
# 0.3087162264032966
# Processing combination 33/60 (eps_value=0.22000000000000003, min_sample=60)
# 0.30341672920648727
# Processing combination 34/60 (eps_value=0.22000000000000003, min_sample=80)
# 0.299968789092236
# Processing combination 35/60 (eps_value=0.22000000000000003, min_sample=100)
# 0.29663638446540536
# Processing combination 36/60 (eps_value=0.22000000000000003, min_sample=120)
# 0.2951245091674855
# Processing combination 37/60 (eps_value=0.24000000000000002, min_sample=20)
# 0.36967828010315423
# Processing combination 38/60 (eps_value=0.24000000000000002, min_sample=40)
# 0.36417277234498324
# Processing combination 39/60 (eps_value=0.24000000000000002, min_sample=60)
# 0.36075942205790484
# Processing combination 40/60 (eps_value=0.24000000000000002, min_sample=80)
# 0.3592552952136169
# Processing combination 41/60 (eps_value=0.24000000000000002, min_sample=100)
# 0.3568230908365996
# Processing combination 42/60 (eps_value=0.24000000000000002, min_sample=120)
# 0.3554364574923045
# Processing combination 43/60 (eps_value=0.26, min_sample=20)
# 0.3676254897085158
# Processing combination 44/60 (eps_value=0.26, min_sample=40)
# 0.37443840268516354
# Processing combination 45/60 (eps_value=0.26, min_sample=60)
# 0.3724916464821775
# Processing combination 46/60 (eps_value=0.26, min_sample=80)
# 0.3751736867701789
# Processing combination 47/60 (eps_value=0.26, min_sample=100)
# 0.3730261292891604
# Processing combination 48/60 (eps_value=0.26, min_sample=120)
# 0.3714754415765442
# Processing combination 49/60 (eps_value=0.28, min_sample=20)
# 0.4770622789361445
# Processing combination 50/60 (eps_value=0.28, min_sample=40)
# 0.47143921279298995
# Processing combination 51/60 (eps_value=0.28, min_sample=60)
# 0.47143921279298995
# Processing combination 52/60 (eps_value=0.28, min_sample=80)
# 0.46830412349580847
# Processing combination 53/60 (eps_value=0.28, min_sample=100)
# 0.4623791248090314
# Processing combination 54/60 (eps_value=0.28, min_sample=120)
# 0.4623791248090314
# Processing combination 55/60 (eps_value=0.30000000000000004, min_sample=20)
# Processing combination 56/60 (eps_value=0.30000000000000004, min_sample=40)
# Processing combination 57/60 (eps_value=0.30000000000000004, min_sample=60)
# Processing combination 58/60 (eps_value=0.30000000000000004, min_sample=80)
# 0.48227358410344945
# Processing combination 59/60 (eps_value=0.30000000000000004, min_sample=100)
# 0.48227358410344945
# Processing combination 60/60 (eps_value=0.30000000000000004, min_sample=120)
# 0.48227358410344945

# %%
df_analysis_gower_no_nan.query("n_clusters > 1").sort_values(by="score", ascending=False)
# Out:
#     eps_value  min_sample     score  n_clusters cluster_types
# 59       0.30         120  0.482274           2       {0, -1}
# 58       0.30         100  0.482274           2       {0, -1}
# 57       0.30          80  0.482274           2       {0, -1}
# 48       0.28          20  0.477062           2       {0, -1}
# 50       0.28          60  0.471439           2       {0, -1}
# 49       0.28          40  0.471439           2       {0, -1}
# 51       0.28          80  0.468304           2       {0, -1}
# 53       0.28         120  0.462379           2       {0, -1}
# 52       0.28         100  0.462379           2       {0, -1}
# 45       0.26          80  0.375174           2       {0, -1}
# 43       0.26          40  0.374438           2       {0, -1}
# 46       0.26         100  0.373026           2       {0, -1}
# 44       0.26          60  0.372492           2       {0, -1}
# 47       0.26         120  0.371475           2       {0, -1}
# 36       0.24          20  0.369678           2       {0, -1}
# 42       0.26          20  0.367625           2       {0, -1}
# 37       0.24          40  0.364173           2       {0, -1}
# 38       0.24          60  0.360759           2       {0, -1}
# 39       0.24          80  0.359255           2       {0, -1}
# 40       0.24         100  0.356823           2       {0, -1}
# 41       0.24         120  0.355436           2       {0, -1}
# 30       0.22          20  0.312641           2       {0, -1}
# 31       0.22          40  0.308716           2       {0, -1}
# 32       0.22          60  0.303417           2       {0, -1}
# 33       0.22          80  0.299969           2       {0, -1}
# 34       0.22         100  0.296636           2       {0, -1}
# 24       0.20          20  0.296384           2       {0, -1}
# 35       0.22         120  0.295125           2       {0, -1}
# 25       0.20          40  0.291154           2       {0, -1}
# 26       0.20          60  0.286442           2       {0, -1}
# 27       0.20          80  0.282099           2       {0, -1}
# 28       0.20         100  0.280168           2       {0, -1}
# 29       0.20         120  0.276529           2       {0, -1}
# 18       0.18          20  0.252258           2       {0, -1}
# 19       0.18          40  0.248009           2       {0, -1}
# 20       0.18          60  0.243355           2       {0, -1}
# 21       0.18          80  0.238833           2       {0, -1}
# 12       0.16          20  0.236248           2       {0, -1}
# 22       0.18         100  0.234674           2       {0, -1}
# 13       0.16          40  0.230204           2       {0, -1}
# 23       0.18         120  0.229664           2       {0, -1}
# 14       0.16          60  0.224286           2       {0, -1}
# 15       0.16          80  0.220409           2       {0, -1}
# 16       0.16         100  0.216259           2       {0, -1}
# 17       0.16         120  0.212742           2       {0, -1}
# 6        0.14          20  0.208215           2       {0, -1}
# 7        0.14          40  0.200844           2       {0, -1}
# 8        0.14          60  0.194833           2       {0, -1}
# 9        0.14          80  0.189084           2       {0, -1}
# 10       0.14         100  0.183563           2       {0, -1}
# 11       0.14         120  0.178078           2       {0, -1}
# 0        0.12          20  0.171927           2       {0, -1}
# 1        0.12          40  0.155430           2       {0, -1}
# 2        0.12          60  0.135682           2       {0, -1}
# 3        0.12          80  0.109487           2       {0, -1}
# 4        0.12         100  0.081652           2       {0, -1}
# 5        0.12         120  0.052922           2       {0, -1}

# %% [markdown]
# # PCA Clustering

# %%
start = 1
end = 2
step = 0.01
eps_values_pca = np.arange(start, end, step)
start = 0
end = 200
step = 20
min_samples_pca = np.arange(start, end, step)
total_combinations = len(eps_values_pca[1:]) * len(min_samples_pca[1:])
total_combinations
# Out:
# 891

# %%
# Path settings csv file
csv_filepath = '../data/interim/pca_non_nan.csv'

# Loading the csv file
data_pca = pd.read_csv(csv_filepath)
print("Data loaded successfully")
# Out:
# Data loaded successfully

# %%
df_analysis_pca = pd.DataFrame(columns=["eps_value", "min_sample", "score", "n_clusters", "cluster_types"])

current_combination = 0

for eps_value in eps_values_pca[1:]:
    for min_sample in min_samples_pca[1:]:
        current_combination += 1
        print(f"Processing combination {current_combination}/{total_combinations} (eps_value={eps_value}, min_sample={min_sample})")

        # Perform DBSCAN clustering
        dbscan_cluster = DBSCAN(eps=eps_value, min_samples=min_sample, metric="euclidean", n_jobs=-1)
        labels = dbscan_cluster.fit_predict(data_pca)
        n_clusters = len(set(labels))
        cluster_types = set(labels)
        try:
            score = silhouette_score(data_pca, labels)
            print(score)
        except ValueError:
            score = 0
        new_row = {'eps_value': eps_value, 'min_sample': min_sample, 'score': score, 'n_clusters': n_clusters,
                   'cluster_types': cluster_types}

        # Adding the new row without using append
        df_analysis_pca.loc[len(df_analysis_pca)] = new_row
# Out:
# Processing combination 1/891 (eps_value=1.01, min_sample=20)
# -0.1773120552615291
# Processing combination 2/891 (eps_value=1.01, min_sample=40)
# Processing combination 3/891 (eps_value=1.01, min_sample=60)
# Processing combination 4/891 (eps_value=1.01, min_sample=80)
# Processing combination 5/891 (eps_value=1.01, min_sample=100)
# Processing combination 6/891 (eps_value=1.01, min_sample=120)
# Processing combination 7/891 (eps_value=1.01, min_sample=140)
# Processing combination 8/891 (eps_value=1.01, min_sample=160)
# Processing combination 9/891 (eps_value=1.01, min_sample=180)
# Processing combination 10/891 (eps_value=1.02, min_sample=20)
# -0.19362047172377123
# Processing combination 11/891 (eps_value=1.02, min_sample=40)
# Processing combination 12/891 (eps_value=1.02, min_sample=60)
# Processing combination 13/891 (eps_value=1.02, min_sample=80)
# Processing combination 14/891 (eps_value=1.02, min_sample=100)
# Processing combination 15/891 (eps_value=1.02, min_sample=120)
# Processing combination 16/891 (eps_value=1.02, min_sample=140)
# Processing combination 17/891 (eps_value=1.02, min_sample=160)
# Processing combination 18/891 (eps_value=1.02, min_sample=180)
# Processing combination 19/891 (eps_value=1.03, min_sample=20)
# -0.1914401625719346
# Processing combination 20/891 (eps_value=1.03, min_sample=40)
# Processing combination 21/891 (eps_value=1.03, min_sample=60)
# Processing combination 22/891 (eps_value=1.03, min_sample=80)
# Processing combination 23/891 (eps_value=1.03, min_sample=100)
# Processing combination 24/891 (eps_value=1.03, min_sample=120)
# Processing combination 25/891 (eps_value=1.03, min_sample=140)
# Processing combination 26/891 (eps_value=1.03, min_sample=160)
# Processing combination 27/891 (eps_value=1.03, min_sample=180)
# Processing combination 28/891 (eps_value=1.04, min_sample=20)
# -0.19752923250661278
# Processing combination 29/891 (eps_value=1.04, min_sample=40)
# Processing combination 30/891 (eps_value=1.04, min_sample=60)
# Processing combination 31/891 (eps_value=1.04, min_sample=80)
# Processing combination 32/891 (eps_value=1.04, min_sample=100)
# Processing combination 33/891 (eps_value=1.04, min_sample=120)
# Processing combination 34/891 (eps_value=1.04, min_sample=140)
# Processing combination 35/891 (eps_value=1.04, min_sample=160)
# Processing combination 36/891 (eps_value=1.04, min_sample=180)
# Processing combination 37/891 (eps_value=1.05, min_sample=20)
# -0.19752923250661278
# Processing combination 38/891 (eps_value=1.05, min_sample=40)
# Processing combination 39/891 (eps_value=1.05, min_sample=60)
# Processing combination 40/891 (eps_value=1.05, min_sample=80)
# Processing combination 41/891 (eps_value=1.05, min_sample=100)
# Processing combination 42/891 (eps_value=1.05, min_sample=120)
# Processing combination 43/891 (eps_value=1.05, min_sample=140)
# Processing combination 44/891 (eps_value=1.05, min_sample=160)
# Processing combination 45/891 (eps_value=1.05, min_sample=180)
# Processing combination 46/891 (eps_value=1.06, min_sample=20)
# -0.221614547176142
# Processing combination 47/891 (eps_value=1.06, min_sample=40)
# Processing combination 48/891 (eps_value=1.06, min_sample=60)
# Processing combination 49/891 (eps_value=1.06, min_sample=80)
# Processing combination 50/891 (eps_value=1.06, min_sample=100)
# Processing combination 51/891 (eps_value=1.06, min_sample=120)
# Processing combination 52/891 (eps_value=1.06, min_sample=140)
# Processing combination 53/891 (eps_value=1.06, min_sample=160)
# Processing combination 54/891 (eps_value=1.06, min_sample=180)
# Processing combination 55/891 (eps_value=1.07, min_sample=20)
# -0.221614547176142
# Processing combination 56/891 (eps_value=1.07, min_sample=40)
# Processing combination 57/891 (eps_value=1.07, min_sample=60)
# Processing combination 58/891 (eps_value=1.07, min_sample=80)
# Processing combination 59/891 (eps_value=1.07, min_sample=100)
# Processing combination 60/891 (eps_value=1.07, min_sample=120)
# Processing combination 61/891 (eps_value=1.07, min_sample=140)
# Processing combination 62/891 (eps_value=1.07, min_sample=160)
# Processing combination 63/891 (eps_value=1.07, min_sample=180)
# Processing combination 64/891 (eps_value=1.08, min_sample=20)
# -0.221614547176142
# Processing combination 65/891 (eps_value=1.08, min_sample=40)
# Processing combination 66/891 (eps_value=1.08, min_sample=60)
# Processing combination 67/891 (eps_value=1.08, min_sample=80)
# Processing combination 68/891 (eps_value=1.08, min_sample=100)
# Processing combination 69/891 (eps_value=1.08, min_sample=120)
# Processing combination 70/891 (eps_value=1.08, min_sample=140)
# Processing combination 71/891 (eps_value=1.08, min_sample=160)
# Processing combination 72/891 (eps_value=1.08, min_sample=180)
# Processing combination 73/891 (eps_value=1.09, min_sample=20)
# -0.221614547176142
# Processing combination 74/891 (eps_value=1.09, min_sample=40)
# Processing combination 75/891 (eps_value=1.09, min_sample=60)
# Processing combination 76/891 (eps_value=1.09, min_sample=80)
# Processing combination 77/891 (eps_value=1.09, min_sample=100)
# Processing combination 78/891 (eps_value=1.09, min_sample=120)
# Processing combination 79/891 (eps_value=1.09, min_sample=140)
# Processing combination 80/891 (eps_value=1.09, min_sample=160)
# Processing combination 81/891 (eps_value=1.09, min_sample=180)
# Processing combination 82/891 (eps_value=1.1, min_sample=20)
# -0.2227409770911414
# Processing combination 83/891 (eps_value=1.1, min_sample=40)
# Processing combination 84/891 (eps_value=1.1, min_sample=60)
# Processing combination 85/891 (eps_value=1.1, min_sample=80)
# Processing combination 86/891 (eps_value=1.1, min_sample=100)
# Processing combination 87/891 (eps_value=1.1, min_sample=120)
# Processing combination 88/891 (eps_value=1.1, min_sample=140)
# Processing combination 89/891 (eps_value=1.1, min_sample=160)
# Processing combination 90/891 (eps_value=1.1, min_sample=180)
# Processing combination 91/891 (eps_value=1.11, min_sample=20)
# -0.2223724360918193
# Processing combination 92/891 (eps_value=1.11, min_sample=40)
# Processing combination 93/891 (eps_value=1.11, min_sample=60)
# Processing combination 94/891 (eps_value=1.11, min_sample=80)
# Processing combination 95/891 (eps_value=1.11, min_sample=100)
# Processing combination 96/891 (eps_value=1.11, min_sample=120)
# Processing combination 97/891 (eps_value=1.11, min_sample=140)
# Processing combination 98/891 (eps_value=1.11, min_sample=160)
# Processing combination 99/891 (eps_value=1.11, min_sample=180)
# Processing combination 100/891 (eps_value=1.12, min_sample=20)
# -0.2223724360918193
# Processing combination 101/891 (eps_value=1.12, min_sample=40)
# Processing combination 102/891 (eps_value=1.12, min_sample=60)
# Processing combination 103/891 (eps_value=1.12, min_sample=80)
# Processing combination 104/891 (eps_value=1.12, min_sample=100)
# Processing combination 105/891 (eps_value=1.12, min_sample=120)
# Processing combination 106/891 (eps_value=1.12, min_sample=140)
# Processing combination 107/891 (eps_value=1.12, min_sample=160)
# Processing combination 108/891 (eps_value=1.12, min_sample=180)
# Processing combination 109/891 (eps_value=1.1300000000000001, min_sample=20)
# -0.2222008529546085
# Processing combination 110/891 (eps_value=1.1300000000000001, min_sample=40)
# Processing combination 111/891 (eps_value=1.1300000000000001, min_sample=60)
# Processing combination 112/891 (eps_value=1.1300000000000001, min_sample=80)
# Processing combination 113/891 (eps_value=1.1300000000000001, min_sample=100)
# Processing combination 114/891 (eps_value=1.1300000000000001, min_sample=120)
# Processing combination 115/891 (eps_value=1.1300000000000001, min_sample=140)
# Processing combination 116/891 (eps_value=1.1300000000000001, min_sample=160)
# Processing combination 117/891 (eps_value=1.1300000000000001, min_sample=180)
# Processing combination 118/891 (eps_value=1.1400000000000001, min_sample=20)
# -0.2222008529546085
# Processing combination 119/891 (eps_value=1.1400000000000001, min_sample=40)
# Processing combination 120/891 (eps_value=1.1400000000000001, min_sample=60)
# Processing combination 121/891 (eps_value=1.1400000000000001, min_sample=80)
# Processing combination 122/891 (eps_value=1.1400000000000001, min_sample=100)
# Processing combination 123/891 (eps_value=1.1400000000000001, min_sample=120)
# Processing combination 124/891 (eps_value=1.1400000000000001, min_sample=140)
# Processing combination 125/891 (eps_value=1.1400000000000001, min_sample=160)
# Processing combination 126/891 (eps_value=1.1400000000000001, min_sample=180)
# Processing combination 127/891 (eps_value=1.1500000000000001, min_sample=20)
# -0.2222008529546085
# Processing combination 128/891 (eps_value=1.1500000000000001, min_sample=40)
# Processing combination 129/891 (eps_value=1.1500000000000001, min_sample=60)
# Processing combination 130/891 (eps_value=1.1500000000000001, min_sample=80)
# Processing combination 131/891 (eps_value=1.1500000000000001, min_sample=100)
# Processing combination 132/891 (eps_value=1.1500000000000001, min_sample=120)
# Processing combination 133/891 (eps_value=1.1500000000000001, min_sample=140)
# Processing combination 134/891 (eps_value=1.1500000000000001, min_sample=160)
# Processing combination 135/891 (eps_value=1.1500000000000001, min_sample=180)
# Processing combination 136/891 (eps_value=1.1600000000000001, min_sample=20)
# -0.2222008529546085
# Processing combination 137/891 (eps_value=1.1600000000000001, min_sample=40)
# Processing combination 138/891 (eps_value=1.1600000000000001, min_sample=60)
# Processing combination 139/891 (eps_value=1.1600000000000001, min_sample=80)
# Processing combination 140/891 (eps_value=1.1600000000000001, min_sample=100)
# Processing combination 141/891 (eps_value=1.1600000000000001, min_sample=120)
# Processing combination 142/891 (eps_value=1.1600000000000001, min_sample=140)
# Processing combination 143/891 (eps_value=1.1600000000000001, min_sample=160)
# Processing combination 144/891 (eps_value=1.1600000000000001, min_sample=180)
# Processing combination 145/891 (eps_value=1.1700000000000002, min_sample=20)
# -0.22212115512816824
# Processing combination 146/891 (eps_value=1.1700000000000002, min_sample=40)
# Processing combination 147/891 (eps_value=1.1700000000000002, min_sample=60)
# Processing combination 148/891 (eps_value=1.1700000000000002, min_sample=80)
# Processing combination 149/891 (eps_value=1.1700000000000002, min_sample=100)
# Processing combination 150/891 (eps_value=1.1700000000000002, min_sample=120)
# Processing combination 151/891 (eps_value=1.1700000000000002, min_sample=140)
# Processing combination 152/891 (eps_value=1.1700000000000002, min_sample=160)
# Processing combination 153/891 (eps_value=1.1700000000000002, min_sample=180)
# Processing combination 154/891 (eps_value=1.1800000000000002, min_sample=20)
# -0.22212115512816824
# Processing combination 155/891 (eps_value=1.1800000000000002, min_sample=40)
# Processing combination 156/891 (eps_value=1.1800000000000002, min_sample=60)
# Processing combination 157/891 (eps_value=1.1800000000000002, min_sample=80)
# Processing combination 158/891 (eps_value=1.1800000000000002, min_sample=100)
# Processing combination 159/891 (eps_value=1.1800000000000002, min_sample=120)
# Processing combination 160/891 (eps_value=1.1800000000000002, min_sample=140)
# Processing combination 161/891 (eps_value=1.1800000000000002, min_sample=160)
# Processing combination 162/891 (eps_value=1.1800000000000002, min_sample=180)
# Processing combination 163/891 (eps_value=1.1900000000000002, min_sample=20)
# -0.22212115512816824
# Processing combination 164/891 (eps_value=1.1900000000000002, min_sample=40)
# Processing combination 165/891 (eps_value=1.1900000000000002, min_sample=60)
# Processing combination 166/891 (eps_value=1.1900000000000002, min_sample=80)
# Processing combination 167/891 (eps_value=1.1900000000000002, min_sample=100)
# Processing combination 168/891 (eps_value=1.1900000000000002, min_sample=120)
# Processing combination 169/891 (eps_value=1.1900000000000002, min_sample=140)
# Processing combination 170/891 (eps_value=1.1900000000000002, min_sample=160)
# Processing combination 171/891 (eps_value=1.1900000000000002, min_sample=180)
# Processing combination 172/891 (eps_value=1.2000000000000002, min_sample=20)
# -0.22212115512816824
# Processing combination 173/891 (eps_value=1.2000000000000002, min_sample=40)
# Processing combination 174/891 (eps_value=1.2000000000000002, min_sample=60)
# Processing combination 175/891 (eps_value=1.2000000000000002, min_sample=80)
# Processing combination 176/891 (eps_value=1.2000000000000002, min_sample=100)
# Processing combination 177/891 (eps_value=1.2000000000000002, min_sample=120)
# Processing combination 178/891 (eps_value=1.2000000000000002, min_sample=140)
# Processing combination 179/891 (eps_value=1.2000000000000002, min_sample=160)
# Processing combination 180/891 (eps_value=1.2000000000000002, min_sample=180)
# Processing combination 181/891 (eps_value=1.2100000000000002, min_sample=20)
# -0.22179654902458035
# Processing combination 182/891 (eps_value=1.2100000000000002, min_sample=40)
# Processing combination 183/891 (eps_value=1.2100000000000002, min_sample=60)
# Processing combination 184/891 (eps_value=1.2100000000000002, min_sample=80)
# Processing combination 185/891 (eps_value=1.2100000000000002, min_sample=100)
# Processing combination 186/891 (eps_value=1.2100000000000002, min_sample=120)
# Processing combination 187/891 (eps_value=1.2100000000000002, min_sample=140)
# Processing combination 188/891 (eps_value=1.2100000000000002, min_sample=160)
# Processing combination 189/891 (eps_value=1.2100000000000002, min_sample=180)
# Processing combination 190/891 (eps_value=1.2200000000000002, min_sample=20)
# -0.22162628161188375
# Processing combination 191/891 (eps_value=1.2200000000000002, min_sample=40)
# Processing combination 192/891 (eps_value=1.2200000000000002, min_sample=60)
# Processing combination 193/891 (eps_value=1.2200000000000002, min_sample=80)
# Processing combination 194/891 (eps_value=1.2200000000000002, min_sample=100)
# Processing combination 195/891 (eps_value=1.2200000000000002, min_sample=120)
# Processing combination 196/891 (eps_value=1.2200000000000002, min_sample=140)
# Processing combination 197/891 (eps_value=1.2200000000000002, min_sample=160)
# Processing combination 198/891 (eps_value=1.2200000000000002, min_sample=180)
# Processing combination 199/891 (eps_value=1.2300000000000002, min_sample=20)
# -0.22162628161188375
# Processing combination 200/891 (eps_value=1.2300000000000002, min_sample=40)
# Processing combination 201/891 (eps_value=1.2300000000000002, min_sample=60)
# Processing combination 202/891 (eps_value=1.2300000000000002, min_sample=80)
# Processing combination 203/891 (eps_value=1.2300000000000002, min_sample=100)
# Processing combination 204/891 (eps_value=1.2300000000000002, min_sample=120)
# Processing combination 205/891 (eps_value=1.2300000000000002, min_sample=140)
# Processing combination 206/891 (eps_value=1.2300000000000002, min_sample=160)
# Processing combination 207/891 (eps_value=1.2300000000000002, min_sample=180)
# Processing combination 208/891 (eps_value=1.2400000000000002, min_sample=20)
# -0.22162628161188375
# Processing combination 209/891 (eps_value=1.2400000000000002, min_sample=40)
# Processing combination 210/891 (eps_value=1.2400000000000002, min_sample=60)
# Processing combination 211/891 (eps_value=1.2400000000000002, min_sample=80)
# Processing combination 212/891 (eps_value=1.2400000000000002, min_sample=100)
# Processing combination 213/891 (eps_value=1.2400000000000002, min_sample=120)
# Processing combination 214/891 (eps_value=1.2400000000000002, min_sample=140)
# Processing combination 215/891 (eps_value=1.2400000000000002, min_sample=160)
# Processing combination 216/891 (eps_value=1.2400000000000002, min_sample=180)
# Processing combination 217/891 (eps_value=1.2500000000000002, min_sample=20)
# -0.2216485904595309
# Processing combination 218/891 (eps_value=1.2500000000000002, min_sample=40)
# Processing combination 219/891 (eps_value=1.2500000000000002, min_sample=60)
# Processing combination 220/891 (eps_value=1.2500000000000002, min_sample=80)
# Processing combination 221/891 (eps_value=1.2500000000000002, min_sample=100)
# Processing combination 222/891 (eps_value=1.2500000000000002, min_sample=120)
# Processing combination 223/891 (eps_value=1.2500000000000002, min_sample=140)
# Processing combination 224/891 (eps_value=1.2500000000000002, min_sample=160)
# Processing combination 225/891 (eps_value=1.2500000000000002, min_sample=180)
# Processing combination 226/891 (eps_value=1.2600000000000002, min_sample=20)
# -0.2216485904595309
# Processing combination 227/891 (eps_value=1.2600000000000002, min_sample=40)
# Processing combination 228/891 (eps_value=1.2600000000000002, min_sample=60)
# Processing combination 229/891 (eps_value=1.2600000000000002, min_sample=80)
# Processing combination 230/891 (eps_value=1.2600000000000002, min_sample=100)
# Processing combination 231/891 (eps_value=1.2600000000000002, min_sample=120)
# Processing combination 232/891 (eps_value=1.2600000000000002, min_sample=140)
# Processing combination 233/891 (eps_value=1.2600000000000002, min_sample=160)
# Processing combination 234/891 (eps_value=1.2600000000000002, min_sample=180)
# Processing combination 235/891 (eps_value=1.2700000000000002, min_sample=20)
# -0.2216485904595309
# Processing combination 236/891 (eps_value=1.2700000000000002, min_sample=40)
# Processing combination 237/891 (eps_value=1.2700000000000002, min_sample=60)
# Processing combination 238/891 (eps_value=1.2700000000000002, min_sample=80)
# Processing combination 239/891 (eps_value=1.2700000000000002, min_sample=100)
# Processing combination 240/891 (eps_value=1.2700000000000002, min_sample=120)
# Processing combination 241/891 (eps_value=1.2700000000000002, min_sample=140)
# Processing combination 242/891 (eps_value=1.2700000000000002, min_sample=160)
# Processing combination 243/891 (eps_value=1.2700000000000002, min_sample=180)
# Processing combination 244/891 (eps_value=1.2800000000000002, min_sample=20)
# -0.2216485904595309
# Processing combination 245/891 (eps_value=1.2800000000000002, min_sample=40)
# Processing combination 246/891 (eps_value=1.2800000000000002, min_sample=60)
# Processing combination 247/891 (eps_value=1.2800000000000002, min_sample=80)
# Processing combination 248/891 (eps_value=1.2800000000000002, min_sample=100)
# Processing combination 249/891 (eps_value=1.2800000000000002, min_sample=120)
# Processing combination 250/891 (eps_value=1.2800000000000002, min_sample=140)
# Processing combination 251/891 (eps_value=1.2800000000000002, min_sample=160)
# Processing combination 252/891 (eps_value=1.2800000000000002, min_sample=180)
# Processing combination 253/891 (eps_value=1.2900000000000003, min_sample=20)
# -0.22136378023887818
# Processing combination 254/891 (eps_value=1.2900000000000003, min_sample=40)
# Processing combination 255/891 (eps_value=1.2900000000000003, min_sample=60)
# Processing combination 256/891 (eps_value=1.2900000000000003, min_sample=80)
# Processing combination 257/891 (eps_value=1.2900000000000003, min_sample=100)
# Processing combination 258/891 (eps_value=1.2900000000000003, min_sample=120)
# Processing combination 259/891 (eps_value=1.2900000000000003, min_sample=140)
# Processing combination 260/891 (eps_value=1.2900000000000003, min_sample=160)
# Processing combination 261/891 (eps_value=1.2900000000000003, min_sample=180)
# Processing combination 262/891 (eps_value=1.3000000000000003, min_sample=20)
# -0.22498446686436122
# Processing combination 263/891 (eps_value=1.3000000000000003, min_sample=40)
# Processing combination 264/891 (eps_value=1.3000000000000003, min_sample=60)
# Processing combination 265/891 (eps_value=1.3000000000000003, min_sample=80)
# Processing combination 266/891 (eps_value=1.3000000000000003, min_sample=100)
# Processing combination 267/891 (eps_value=1.3000000000000003, min_sample=120)
# Processing combination 268/891 (eps_value=1.3000000000000003, min_sample=140)
# Processing combination 269/891 (eps_value=1.3000000000000003, min_sample=160)
# Processing combination 270/891 (eps_value=1.3000000000000003, min_sample=180)
# Processing combination 271/891 (eps_value=1.3100000000000003, min_sample=20)
# -0.21903170917858047
# Processing combination 272/891 (eps_value=1.3100000000000003, min_sample=40)
# Processing combination 273/891 (eps_value=1.3100000000000003, min_sample=60)
# Processing combination 274/891 (eps_value=1.3100000000000003, min_sample=80)
# Processing combination 275/891 (eps_value=1.3100000000000003, min_sample=100)
# Processing combination 276/891 (eps_value=1.3100000000000003, min_sample=120)
# Processing combination 277/891 (eps_value=1.3100000000000003, min_sample=140)
# Processing combination 278/891 (eps_value=1.3100000000000003, min_sample=160)
# Processing combination 279/891 (eps_value=1.3100000000000003, min_sample=180)
# Processing combination 280/891 (eps_value=1.3200000000000003, min_sample=20)
# -0.21869832385828517
# Processing combination 281/891 (eps_value=1.3200000000000003, min_sample=40)
# -0.12509071850677012
# Processing combination 282/891 (eps_value=1.3200000000000003, min_sample=60)
# Processing combination 283/891 (eps_value=1.3200000000000003, min_sample=80)
# Processing combination 284/891 (eps_value=1.3200000000000003, min_sample=100)
# Processing combination 285/891 (eps_value=1.3200000000000003, min_sample=120)
# Processing combination 286/891 (eps_value=1.3200000000000003, min_sample=140)
# Processing combination 287/891 (eps_value=1.3200000000000003, min_sample=160)
# Processing combination 288/891 (eps_value=1.3200000000000003, min_sample=180)
# Processing combination 289/891 (eps_value=1.3300000000000003, min_sample=20)
# -0.21771645127607472
# Processing combination 290/891 (eps_value=1.3300000000000003, min_sample=40)
# -0.12507744267448284
# Processing combination 291/891 (eps_value=1.3300000000000003, min_sample=60)
# Processing combination 292/891 (eps_value=1.3300000000000003, min_sample=80)
# Processing combination 293/891 (eps_value=1.3300000000000003, min_sample=100)
# Processing combination 294/891 (eps_value=1.3300000000000003, min_sample=120)
# Processing combination 295/891 (eps_value=1.3300000000000003, min_sample=140)
# Processing combination 296/891 (eps_value=1.3300000000000003, min_sample=160)
# Processing combination 297/891 (eps_value=1.3300000000000003, min_sample=180)
# Processing combination 298/891 (eps_value=1.3400000000000003, min_sample=20)
# -0.2203010959050705
# Processing combination 299/891 (eps_value=1.3400000000000003, min_sample=40)
# -0.12466148417716823
# Processing combination 300/891 (eps_value=1.3400000000000003, min_sample=60)
# Processing combination 301/891 (eps_value=1.3400000000000003, min_sample=80)
# Processing combination 302/891 (eps_value=1.3400000000000003, min_sample=100)
# Processing combination 303/891 (eps_value=1.3400000000000003, min_sample=120)
# Processing combination 304/891 (eps_value=1.3400000000000003, min_sample=140)
# Processing combination 305/891 (eps_value=1.3400000000000003, min_sample=160)
# Processing combination 306/891 (eps_value=1.3400000000000003, min_sample=180)
# Processing combination 307/891 (eps_value=1.3500000000000003, min_sample=20)
# -0.2001510630395092
# Processing combination 308/891 (eps_value=1.3500000000000003, min_sample=40)
# -0.1558495360233344
# Processing combination 309/891 (eps_value=1.3500000000000003, min_sample=60)
# -0.12343456524554465
# Processing combination 310/891 (eps_value=1.3500000000000003, min_sample=80)
# Processing combination 311/891 (eps_value=1.3500000000000003, min_sample=100)
# Processing combination 312/891 (eps_value=1.3500000000000003, min_sample=120)
# Processing combination 313/891 (eps_value=1.3500000000000003, min_sample=140)
# Processing combination 314/891 (eps_value=1.3500000000000003, min_sample=160)
# Processing combination 315/891 (eps_value=1.3500000000000003, min_sample=180)
# Processing combination 316/891 (eps_value=1.3600000000000003, min_sample=20)
# -0.1817242580209852
# Processing combination 317/891 (eps_value=1.3600000000000003, min_sample=40)
# -0.1549279126561555
# Processing combination 318/891 (eps_value=1.3600000000000003, min_sample=60)
# -0.12343456524554465
# Processing combination 319/891 (eps_value=1.3600000000000003, min_sample=80)
# Processing combination 320/891 (eps_value=1.3600000000000003, min_sample=100)
# Processing combination 321/891 (eps_value=1.3600000000000003, min_sample=120)
# Processing combination 322/891 (eps_value=1.3600000000000003, min_sample=140)
# Processing combination 323/891 (eps_value=1.3600000000000003, min_sample=160)
# Processing combination 324/891 (eps_value=1.3600000000000003, min_sample=180)
# Processing combination 325/891 (eps_value=1.3700000000000003, min_sample=20)
# -0.18349159304439788
# Processing combination 326/891 (eps_value=1.3700000000000003, min_sample=40)
# -0.1549279126561555
# Processing combination 327/891 (eps_value=1.3700000000000003, min_sample=60)
# -0.12343456524554465
# Processing combination 328/891 (eps_value=1.3700000000000003, min_sample=80)
# Processing combination 329/891 (eps_value=1.3700000000000003, min_sample=100)
# Processing combination 330/891 (eps_value=1.3700000000000003, min_sample=120)
# Processing combination 331/891 (eps_value=1.3700000000000003, min_sample=140)
# Processing combination 332/891 (eps_value=1.3700000000000003, min_sample=160)
# Processing combination 333/891 (eps_value=1.3700000000000003, min_sample=180)
# Processing combination 334/891 (eps_value=1.3800000000000003, min_sample=20)
# -0.18620152063389356
# Processing combination 335/891 (eps_value=1.3800000000000003, min_sample=40)
# -0.1795926537675651
# Processing combination 336/891 (eps_value=1.3800000000000003, min_sample=60)
# -0.1231684106636461
# Processing combination 337/891 (eps_value=1.3800000000000003, min_sample=80)
# Processing combination 338/891 (eps_value=1.3800000000000003, min_sample=100)
# Processing combination 339/891 (eps_value=1.3800000000000003, min_sample=120)
# Processing combination 340/891 (eps_value=1.3800000000000003, min_sample=140)
# Processing combination 341/891 (eps_value=1.3800000000000003, min_sample=160)
# Processing combination 342/891 (eps_value=1.3800000000000003, min_sample=180)
# Processing combination 343/891 (eps_value=1.3900000000000003, min_sample=20)
# -0.1668449298006484
# Processing combination 344/891 (eps_value=1.3900000000000003, min_sample=40)
# -0.16367648775238178
# Processing combination 345/891 (eps_value=1.3900000000000003, min_sample=60)
# -0.12164238047053931
# Processing combination 346/891 (eps_value=1.3900000000000003, min_sample=80)
# Processing combination 347/891 (eps_value=1.3900000000000003, min_sample=100)
# Processing combination 348/891 (eps_value=1.3900000000000003, min_sample=120)
# Processing combination 349/891 (eps_value=1.3900000000000003, min_sample=140)
# Processing combination 350/891 (eps_value=1.3900000000000003, min_sample=160)
# Processing combination 351/891 (eps_value=1.3900000000000003, min_sample=180)
# Processing combination 352/891 (eps_value=1.4000000000000004, min_sample=20)
# -0.16420789439484124
# Processing combination 353/891 (eps_value=1.4000000000000004, min_sample=40)
# -0.17706410387319788
# Processing combination 354/891 (eps_value=1.4000000000000004, min_sample=60)
# -0.12073234568786073
# Processing combination 355/891 (eps_value=1.4000000000000004, min_sample=80)
# Processing combination 356/891 (eps_value=1.4000000000000004, min_sample=100)
# Processing combination 357/891 (eps_value=1.4000000000000004, min_sample=120)
# Processing combination 358/891 (eps_value=1.4000000000000004, min_sample=140)
# Processing combination 359/891 (eps_value=1.4000000000000004, min_sample=160)
# Processing combination 360/891 (eps_value=1.4000000000000004, min_sample=180)
# Processing combination 361/891 (eps_value=1.4100000000000004, min_sample=20)
# -0.17167583791830776
# Processing combination 362/891 (eps_value=1.4100000000000004, min_sample=40)
# -0.1636882710668679
# Processing combination 363/891 (eps_value=1.4100000000000004, min_sample=60)
# -0.1551208854206971
# Processing combination 364/891 (eps_value=1.4100000000000004, min_sample=80)
# Processing combination 365/891 (eps_value=1.4100000000000004, min_sample=100)
# Processing combination 366/891 (eps_value=1.4100000000000004, min_sample=120)
# Processing combination 367/891 (eps_value=1.4100000000000004, min_sample=140)
# Processing combination 368/891 (eps_value=1.4100000000000004, min_sample=160)
# Processing combination 369/891 (eps_value=1.4100000000000004, min_sample=180)
# Processing combination 370/891 (eps_value=1.4200000000000004, min_sample=20)
# -0.02149026575455395
# Processing combination 371/891 (eps_value=1.4200000000000004, min_sample=40)
# -0.060194470242271085
# Processing combination 372/891 (eps_value=1.4200000000000004, min_sample=60)
# -0.16396608523355044
# Processing combination 373/891 (eps_value=1.4200000000000004, min_sample=80)
# -0.12230752441522634
# Processing combination 374/891 (eps_value=1.4200000000000004, min_sample=100)
# Processing combination 375/891 (eps_value=1.4200000000000004, min_sample=120)
# Processing combination 376/891 (eps_value=1.4200000000000004, min_sample=140)
# Processing combination 377/891 (eps_value=1.4200000000000004, min_sample=160)
# Processing combination 378/891 (eps_value=1.4200000000000004, min_sample=180)
# Processing combination 379/891 (eps_value=1.4300000000000004, min_sample=20)
# -0.019626033478751092
# Processing combination 380/891 (eps_value=1.4300000000000004, min_sample=40)
# -0.05826396674378983
# Processing combination 381/891 (eps_value=1.4300000000000004, min_sample=60)
# -0.13171035964366096
# Processing combination 382/891 (eps_value=1.4300000000000004, min_sample=80)
# -0.12230752441522634
# Processing combination 383/891 (eps_value=1.4300000000000004, min_sample=100)
# Processing combination 384/891 (eps_value=1.4300000000000004, min_sample=120)
# Processing combination 385/891 (eps_value=1.4300000000000004, min_sample=140)
# Processing combination 386/891 (eps_value=1.4300000000000004, min_sample=160)
# Processing combination 387/891 (eps_value=1.4300000000000004, min_sample=180)
# Processing combination 388/891 (eps_value=1.4400000000000004, min_sample=20)
# -0.01856895596796518
# Processing combination 389/891 (eps_value=1.4400000000000004, min_sample=40)
# -0.05543065035113573
# Processing combination 390/891 (eps_value=1.4400000000000004, min_sample=60)
# -0.12931369229958253
# Processing combination 391/891 (eps_value=1.4400000000000004, min_sample=80)
# -0.12204494013361838
# Processing combination 392/891 (eps_value=1.4400000000000004, min_sample=100)
# Processing combination 393/891 (eps_value=1.4400000000000004, min_sample=120)
# Processing combination 394/891 (eps_value=1.4400000000000004, min_sample=140)
# Processing combination 395/891 (eps_value=1.4400000000000004, min_sample=160)
# Processing combination 396/891 (eps_value=1.4400000000000004, min_sample=180)
# Processing combination 397/891 (eps_value=1.4500000000000004, min_sample=20)
# -0.017614766178029064
# Processing combination 398/891 (eps_value=1.4500000000000004, min_sample=40)
# -0.05461725932961332
# Processing combination 399/891 (eps_value=1.4500000000000004, min_sample=60)
# -0.12419187481796569
# Processing combination 400/891 (eps_value=1.4500000000000004, min_sample=80)
# -0.12204494013361838
# Processing combination 401/891 (eps_value=1.4500000000000004, min_sample=100)
# Processing combination 402/891 (eps_value=1.4500000000000004, min_sample=120)
# Processing combination 403/891 (eps_value=1.4500000000000004, min_sample=140)
# Processing combination 404/891 (eps_value=1.4500000000000004, min_sample=160)
# Processing combination 405/891 (eps_value=1.4500000000000004, min_sample=180)
# Processing combination 406/891 (eps_value=1.4600000000000004, min_sample=20)
# -0.016311679774070127
# Processing combination 407/891 (eps_value=1.4600000000000004, min_sample=40)
# -0.05163972770194345
# Processing combination 408/891 (eps_value=1.4600000000000004, min_sample=60)
# -0.12391171502857892
# Processing combination 409/891 (eps_value=1.4600000000000004, min_sample=80)
# -0.15043601014411837
# Processing combination 410/891 (eps_value=1.4600000000000004, min_sample=100)
# Processing combination 411/891 (eps_value=1.4600000000000004, min_sample=120)
# Processing combination 412/891 (eps_value=1.4600000000000004, min_sample=140)
# Processing combination 413/891 (eps_value=1.4600000000000004, min_sample=160)
# Processing combination 414/891 (eps_value=1.4600000000000004, min_sample=180)
# Processing combination 415/891 (eps_value=1.4700000000000004, min_sample=20)
# -0.015213927111970272
# Processing combination 416/891 (eps_value=1.4700000000000004, min_sample=40)
# -0.05129220468452486
# Processing combination 417/891 (eps_value=1.4700000000000004, min_sample=60)
# -0.12319527236664544
# Processing combination 418/891 (eps_value=1.4700000000000004, min_sample=80)
# -0.15043601014411837
# Processing combination 419/891 (eps_value=1.4700000000000004, min_sample=100)
# Processing combination 420/891 (eps_value=1.4700000000000004, min_sample=120)
# Processing combination 421/891 (eps_value=1.4700000000000004, min_sample=140)
# Processing combination 422/891 (eps_value=1.4700000000000004, min_sample=160)
# Processing combination 423/891 (eps_value=1.4700000000000004, min_sample=180)
# Processing combination 424/891 (eps_value=1.4800000000000004, min_sample=20)
# -0.01300692785847871
# Processing combination 425/891 (eps_value=1.4800000000000004, min_sample=40)
# -0.04808042906546953
# Processing combination 426/891 (eps_value=1.4800000000000004, min_sample=60)
# -0.12307576689571419
# Processing combination 427/891 (eps_value=1.4800000000000004, min_sample=80)
# -0.15051403201759095
# Processing combination 428/891 (eps_value=1.4800000000000004, min_sample=100)
# Processing combination 429/891 (eps_value=1.4800000000000004, min_sample=120)
# Processing combination 430/891 (eps_value=1.4800000000000004, min_sample=140)
# Processing combination 431/891 (eps_value=1.4800000000000004, min_sample=160)
# Processing combination 432/891 (eps_value=1.4800000000000004, min_sample=180)
# Processing combination 433/891 (eps_value=1.4900000000000004, min_sample=20)
# -0.010999697029884355
# Processing combination 434/891 (eps_value=1.4900000000000004, min_sample=40)
# -0.046781854685665154
# Processing combination 435/891 (eps_value=1.4900000000000004, min_sample=60)
# -0.11424820752380224
# Processing combination 436/891 (eps_value=1.4900000000000004, min_sample=80)
# -0.15029916094484963
# Processing combination 437/891 (eps_value=1.4900000000000004, min_sample=100)
# Processing combination 438/891 (eps_value=1.4900000000000004, min_sample=120)
# Processing combination 439/891 (eps_value=1.4900000000000004, min_sample=140)
# Processing combination 440/891 (eps_value=1.4900000000000004, min_sample=160)
# Processing combination 441/891 (eps_value=1.4900000000000004, min_sample=180)
# Processing combination 442/891 (eps_value=1.5000000000000004, min_sample=20)
# -0.010752179911879566
# Processing combination 443/891 (eps_value=1.5000000000000004, min_sample=40)
# -0.04648077512045655
# Processing combination 444/891 (eps_value=1.5000000000000004, min_sample=60)
# -0.11412622246509932
# Processing combination 445/891 (eps_value=1.5000000000000004, min_sample=80)
# -0.1417100874763449
# Processing combination 446/891 (eps_value=1.5000000000000004, min_sample=100)
# Processing combination 447/891 (eps_value=1.5000000000000004, min_sample=120)
# Processing combination 448/891 (eps_value=1.5000000000000004, min_sample=140)
# Processing combination 449/891 (eps_value=1.5000000000000004, min_sample=160)
# Processing combination 450/891 (eps_value=1.5000000000000004, min_sample=180)
# Processing combination 451/891 (eps_value=1.5100000000000005, min_sample=20)
# -0.01054273611517084
# Processing combination 452/891 (eps_value=1.5100000000000005, min_sample=40)
# -0.046483371325600785
# Processing combination 453/891 (eps_value=1.5100000000000005, min_sample=60)
# -0.11412622246509932
# Processing combination 454/891 (eps_value=1.5100000000000005, min_sample=80)
# -0.1417496667797225
# Processing combination 455/891 (eps_value=1.5100000000000005, min_sample=100)
# Processing combination 456/891 (eps_value=1.5100000000000005, min_sample=120)
# Processing combination 457/891 (eps_value=1.5100000000000005, min_sample=140)
# Processing combination 458/891 (eps_value=1.5100000000000005, min_sample=160)
# Processing combination 459/891 (eps_value=1.5100000000000005, min_sample=180)
# Processing combination 460/891 (eps_value=1.5200000000000005, min_sample=20)
# -0.010242957799234264
# Processing combination 461/891 (eps_value=1.5200000000000005, min_sample=40)
# -0.04624506275684319
# Processing combination 462/891 (eps_value=1.5200000000000005, min_sample=60)
# -0.114036155900533
# Processing combination 463/891 (eps_value=1.5200000000000005, min_sample=80)
# -0.14148679460962835
# Processing combination 464/891 (eps_value=1.5200000000000005, min_sample=100)
# Processing combination 465/891 (eps_value=1.5200000000000005, min_sample=120)
# Processing combination 466/891 (eps_value=1.5200000000000005, min_sample=140)
# Processing combination 467/891 (eps_value=1.5200000000000005, min_sample=160)
# Processing combination 468/891 (eps_value=1.5200000000000005, min_sample=180)
# Processing combination 469/891 (eps_value=1.5300000000000005, min_sample=20)
# -0.009760091702329738
# Processing combination 470/891 (eps_value=1.5300000000000005, min_sample=40)
# -0.04610739192548613
# Processing combination 471/891 (eps_value=1.5300000000000005, min_sample=60)
# -0.11390514454017102
# Processing combination 472/891 (eps_value=1.5300000000000005, min_sample=80)
# -0.14114694308624995
# Processing combination 473/891 (eps_value=1.5300000000000005, min_sample=100)
# Processing combination 474/891 (eps_value=1.5300000000000005, min_sample=120)
# Processing combination 475/891 (eps_value=1.5300000000000005, min_sample=140)
# Processing combination 476/891 (eps_value=1.5300000000000005, min_sample=160)
# Processing combination 477/891 (eps_value=1.5300000000000005, min_sample=180)
# Processing combination 478/891 (eps_value=1.5400000000000005, min_sample=20)
# -0.009362475890694178
# Processing combination 479/891 (eps_value=1.5400000000000005, min_sample=40)
# -0.0460359556675412
# Processing combination 480/891 (eps_value=1.5400000000000005, min_sample=60)
# -0.07690834424323194
# Processing combination 481/891 (eps_value=1.5400000000000005, min_sample=80)
# -0.14114694308624995
# Processing combination 482/891 (eps_value=1.5400000000000005, min_sample=100)
# Processing combination 483/891 (eps_value=1.5400000000000005, min_sample=120)
# Processing combination 484/891 (eps_value=1.5400000000000005, min_sample=140)
# Processing combination 485/891 (eps_value=1.5400000000000005, min_sample=160)
# Processing combination 486/891 (eps_value=1.5400000000000005, min_sample=180)
# Processing combination 487/891 (eps_value=1.5500000000000005, min_sample=20)
# -0.008972059253521184
# Processing combination 488/891 (eps_value=1.5500000000000005, min_sample=40)
# -0.0455628373316856
# Processing combination 489/891 (eps_value=1.5500000000000005, min_sample=60)
# -0.07687607583197775
# Processing combination 490/891 (eps_value=1.5500000000000005, min_sample=80)
# -0.0992881236176498
# Processing combination 491/891 (eps_value=1.5500000000000005, min_sample=100)
# Processing combination 492/891 (eps_value=1.5500000000000005, min_sample=120)
# Processing combination 493/891 (eps_value=1.5500000000000005, min_sample=140)
# Processing combination 494/891 (eps_value=1.5500000000000005, min_sample=160)
# Processing combination 495/891 (eps_value=1.5500000000000005, min_sample=180)
# Processing combination 496/891 (eps_value=1.5600000000000005, min_sample=20)
# -0.008487245990677957
# Processing combination 497/891 (eps_value=1.5600000000000005, min_sample=40)
# -0.045432689393409185
# Processing combination 498/891 (eps_value=1.5600000000000005, min_sample=60)
# -0.0766874588193941
# Processing combination 499/891 (eps_value=1.5600000000000005, min_sample=80)
# -0.09921338004389117
# Processing combination 500/891 (eps_value=1.5600000000000005, min_sample=100)
# Processing combination 501/891 (eps_value=1.5600000000000005, min_sample=120)
# Processing combination 502/891 (eps_value=1.5600000000000005, min_sample=140)
# Processing combination 503/891 (eps_value=1.5600000000000005, min_sample=160)
# Processing combination 504/891 (eps_value=1.5600000000000005, min_sample=180)
# Processing combination 505/891 (eps_value=1.5700000000000005, min_sample=20)
# -0.007160547177048168
# Processing combination 506/891 (eps_value=1.5700000000000005, min_sample=40)
# -0.04458701101458328
# Processing combination 507/891 (eps_value=1.5700000000000005, min_sample=60)
# -0.07649845781465558
# Processing combination 508/891 (eps_value=1.5700000000000005, min_sample=80)
# -0.09921338004389117
# Processing combination 509/891 (eps_value=1.5700000000000005, min_sample=100)
# Processing combination 510/891 (eps_value=1.5700000000000005, min_sample=120)
# Processing combination 511/891 (eps_value=1.5700000000000005, min_sample=140)
# Processing combination 512/891 (eps_value=1.5700000000000005, min_sample=160)
# Processing combination 513/891 (eps_value=1.5700000000000005, min_sample=180)
# Processing combination 514/891 (eps_value=1.5800000000000005, min_sample=20)
# -0.006434061198520268
# Processing combination 515/891 (eps_value=1.5800000000000005, min_sample=40)
# -0.04446802116336484
# Processing combination 516/891 (eps_value=1.5800000000000005, min_sample=60)
# -0.07615460149121671
# Processing combination 517/891 (eps_value=1.5800000000000005, min_sample=80)
# -0.098515783989347
# Processing combination 518/891 (eps_value=1.5800000000000005, min_sample=100)
# Processing combination 519/891 (eps_value=1.5800000000000005, min_sample=120)
# Processing combination 520/891 (eps_value=1.5800000000000005, min_sample=140)
# Processing combination 521/891 (eps_value=1.5800000000000005, min_sample=160)
# Processing combination 522/891 (eps_value=1.5800000000000005, min_sample=180)
# Processing combination 523/891 (eps_value=1.5900000000000005, min_sample=20)
# -0.00418868995020118
# Processing combination 524/891 (eps_value=1.5900000000000005, min_sample=40)
# -0.04251865261990456
# Processing combination 525/891 (eps_value=1.5900000000000005, min_sample=60)
# -0.07582699572110257
# Processing combination 526/891 (eps_value=1.5900000000000005, min_sample=80)
# -0.09815237747315926
# Processing combination 527/891 (eps_value=1.5900000000000005, min_sample=100)
# Processing combination 528/891 (eps_value=1.5900000000000005, min_sample=120)
# Processing combination 529/891 (eps_value=1.5900000000000005, min_sample=140)
# Processing combination 530/891 (eps_value=1.5900000000000005, min_sample=160)
# Processing combination 531/891 (eps_value=1.5900000000000005, min_sample=180)
# Processing combination 532/891 (eps_value=1.6000000000000005, min_sample=20)
# -0.003238200329433884
# Processing combination 533/891 (eps_value=1.6000000000000005, min_sample=40)
# -0.04150684220691975
# Processing combination 534/891 (eps_value=1.6000000000000005, min_sample=60)
# -0.07566125060010463
# Processing combination 535/891 (eps_value=1.6000000000000005, min_sample=80)
# -0.09782238029310723
# Processing combination 536/891 (eps_value=1.6000000000000005, min_sample=100)
# Processing combination 537/891 (eps_value=1.6000000000000005, min_sample=120)
# Processing combination 538/891 (eps_value=1.6000000000000005, min_sample=140)
# Processing combination 539/891 (eps_value=1.6000000000000005, min_sample=160)
# Processing combination 540/891 (eps_value=1.6000000000000005, min_sample=180)
# Processing combination 541/891 (eps_value=1.6100000000000005, min_sample=20)
# -0.0022777331640149007
# Processing combination 542/891 (eps_value=1.6100000000000005, min_sample=40)
# -0.04024500528815953
# Processing combination 543/891 (eps_value=1.6100000000000005, min_sample=60)
# -0.07473292436542221
# Processing combination 544/891 (eps_value=1.6100000000000005, min_sample=80)
# -0.0968170443047015
# Processing combination 545/891 (eps_value=1.6100000000000005, min_sample=100)
# Processing combination 546/891 (eps_value=1.6100000000000005, min_sample=120)
# Processing combination 547/891 (eps_value=1.6100000000000005, min_sample=140)
# Processing combination 548/891 (eps_value=1.6100000000000005, min_sample=160)
# Processing combination 549/891 (eps_value=1.6100000000000005, min_sample=180)
# Processing combination 550/891 (eps_value=1.6200000000000006, min_sample=20)
# -0.001156679081588533
# Processing combination 551/891 (eps_value=1.6200000000000006, min_sample=40)
# -0.039228117103626094
# Processing combination 552/891 (eps_value=1.6200000000000006, min_sample=60)
# -0.07434346975281116
# Processing combination 553/891 (eps_value=1.6200000000000006, min_sample=80)
# -0.0968170443047015
# Processing combination 554/891 (eps_value=1.6200000000000006, min_sample=100)
# Processing combination 555/891 (eps_value=1.6200000000000006, min_sample=120)
# Processing combination 556/891 (eps_value=1.6200000000000006, min_sample=140)
# Processing combination 557/891 (eps_value=1.6200000000000006, min_sample=160)
# Processing combination 558/891 (eps_value=1.6200000000000006, min_sample=180)
# Processing combination 559/891 (eps_value=1.6300000000000006, min_sample=20)
# 0.001226076192496072
# Processing combination 560/891 (eps_value=1.6300000000000006, min_sample=40)
# -0.03663358987703947
# Processing combination 561/891 (eps_value=1.6300000000000006, min_sample=60)
# -0.07161621430912606
# Processing combination 562/891 (eps_value=1.6300000000000006, min_sample=80)
# -0.09718720094830036
# Processing combination 563/891 (eps_value=1.6300000000000006, min_sample=100)
# Processing combination 564/891 (eps_value=1.6300000000000006, min_sample=120)
# Processing combination 565/891 (eps_value=1.6300000000000006, min_sample=140)
# Processing combination 566/891 (eps_value=1.6300000000000006, min_sample=160)
# Processing combination 567/891 (eps_value=1.6300000000000006, min_sample=180)
# Processing combination 568/891 (eps_value=1.6400000000000006, min_sample=20)
# 0.0023459087798614222
# Processing combination 569/891 (eps_value=1.6400000000000006, min_sample=40)
# -0.03604721028357525
# Processing combination 570/891 (eps_value=1.6400000000000006, min_sample=60)
# -0.06688573853083342
# Processing combination 571/891 (eps_value=1.6400000000000006, min_sample=80)
# -0.09638443524458659
# Processing combination 572/891 (eps_value=1.6400000000000006, min_sample=100)
# Processing combination 573/891 (eps_value=1.6400000000000006, min_sample=120)
# Processing combination 574/891 (eps_value=1.6400000000000006, min_sample=140)
# Processing combination 575/891 (eps_value=1.6400000000000006, min_sample=160)
# Processing combination 576/891 (eps_value=1.6400000000000006, min_sample=180)
# Processing combination 577/891 (eps_value=1.6500000000000006, min_sample=20)
# 0.0033833406480125615
# Processing combination 578/891 (eps_value=1.6500000000000006, min_sample=40)
# -0.03414270090760469
# Processing combination 579/891 (eps_value=1.6500000000000006, min_sample=60)
# -0.06483453682910888
# Processing combination 580/891 (eps_value=1.6500000000000006, min_sample=80)
# -0.09394365490147485
# Processing combination 581/891 (eps_value=1.6500000000000006, min_sample=100)
# -0.10577092501407177
# Processing combination 582/891 (eps_value=1.6500000000000006, min_sample=120)
# -0.10322937502780066
# Processing combination 583/891 (eps_value=1.6500000000000006, min_sample=140)
# Processing combination 584/891 (eps_value=1.6500000000000006, min_sample=160)
# Processing combination 585/891 (eps_value=1.6500000000000006, min_sample=180)
# Processing combination 586/891 (eps_value=1.6600000000000006, min_sample=20)
# 0.00698154075685937
# Processing combination 587/891 (eps_value=1.6600000000000006, min_sample=40)
# -0.03099786581968145
# Processing combination 588/891 (eps_value=1.6600000000000006, min_sample=60)
# -0.058638936479324257
# Processing combination 589/891 (eps_value=1.6600000000000006, min_sample=80)
# -0.08955908694960067
# Processing combination 590/891 (eps_value=1.6600000000000006, min_sample=100)
# -0.0927058179204352
# Processing combination 591/891 (eps_value=1.6600000000000006, min_sample=120)
# -0.08903922541211234
# Processing combination 592/891 (eps_value=1.6600000000000006, min_sample=140)
# -0.08903922541211234
# Processing combination 593/891 (eps_value=1.6600000000000006, min_sample=160)
# -0.08903922541211234
# Processing combination 594/891 (eps_value=1.6600000000000006, min_sample=180)
# -0.08903922541211234
# Processing combination 595/891 (eps_value=1.6700000000000006, min_sample=20)
# 0.011651340365844498
# ...
# -0.03641517397886516
# Processing combination 730/891 (eps_value=1.8200000000000007, min_sample=20)
# 0.06678664875752889
# Processing combination 731/891 (eps_value=1.8200000000000007, min_sample=40)
# 0.0469049955686879
# Processing combination 732/891 (eps_value=1.8200000000000007, min_sample=60)
# 0.03241003583865181
# Processing combination 733/891 (eps_value=1.8200000000000007, min_sample=80)
# 0.016384114856679143
# Processing combination 734/891 (eps_value=1.8200000000000007, min_sample=100)
# 0.0026708677926816546
# Processing combination 735/891 (eps_value=1.8200000000000007, min_sample=120)
# -0.008280318892943445
# Processing combination 736/891 (eps_value=1.8200000000000007, min_sample=140)
# -0.01750756097697656
# Processing combination 737/891 (eps_value=1.8200000000000007, min_sample=160)
# -0.028421897324607592
# Processing combination 738/891 (eps_value=1.8200000000000007, min_sample=180)
# -0.035650300678476875
# Processing combination 739/891 (eps_value=1.8300000000000007, min_sample=20)
# 0.06766864006357012
# Processing combination 740/891 (eps_value=1.8300000000000007, min_sample=40)
# 0.04814910781908727
# Processing combination 741/891 (eps_value=1.8300000000000007, min_sample=60)
# 0.0330540283575643
# Processing combination 742/891 (eps_value=1.8300000000000007, min_sample=80)
# 0.01695604161561513
# Processing combination 743/891 (eps_value=1.8300000000000007, min_sample=100)
# 0.0030833320293197084
# Processing combination 744/891 (eps_value=1.8300000000000007, min_sample=120)
# -0.007104222060599648
# Processing combination 745/891 (eps_value=1.8300000000000007, min_sample=140)
# -0.017412461518522087
# Processing combination 746/891 (eps_value=1.8300000000000007, min_sample=160)
# -0.0282319490710994
# Processing combination 747/891 (eps_value=1.8300000000000007, min_sample=180)
# -0.03475003017223659
# Processing combination 748/891 (eps_value=1.8400000000000007, min_sample=20)
# 0.06868909198351843
# Processing combination 749/891 (eps_value=1.8400000000000007, min_sample=40)
# 0.049263548164358295
# Processing combination 750/891 (eps_value=1.8400000000000007, min_sample=60)
# 0.034210790424115116
# Processing combination 751/891 (eps_value=1.8400000000000007, min_sample=80)
# 0.01791889285934045
# Processing combination 752/891 (eps_value=1.8400000000000007, min_sample=100)
# 0.003912532602040241
# Processing combination 753/891 (eps_value=1.8400000000000007, min_sample=120)
# -0.006565094338828094
# Processing combination 754/891 (eps_value=1.8400000000000007, min_sample=140)
# -0.016721550175239262
# Processing combination 755/891 (eps_value=1.8400000000000007, min_sample=160)
# -0.02787719757615782
# Processing combination 756/891 (eps_value=1.8400000000000007, min_sample=180)
# -0.03436297021199791
# Processing combination 757/891 (eps_value=1.8500000000000008, min_sample=20)
# 0.06943940232636768
# Processing combination 758/891 (eps_value=1.8500000000000008, min_sample=40)
# 0.05001264256094216
# Processing combination 759/891 (eps_value=1.8500000000000008, min_sample=60)
# 0.03488138984200836
# Processing combination 760/891 (eps_value=1.8500000000000008, min_sample=80)
# 0.0185826328248233
# Processing combination 761/891 (eps_value=1.8500000000000008, min_sample=100)
# 0.004449933351924249
# Processing combination 762/891 (eps_value=1.8500000000000008, min_sample=120)
# -0.005878192747747841
# Processing combination 763/891 (eps_value=1.8500000000000008, min_sample=140)
# -0.0161662624865365
# Processing combination 764/891 (eps_value=1.8500000000000008, min_sample=160)
# -0.027387556785925454
# Processing combination 765/891 (eps_value=1.8500000000000008, min_sample=180)
# -0.0338289638699873
# Processing combination 766/891 (eps_value=1.8600000000000008, min_sample=20)
# 0.07048628516499254
# Processing combination 767/891 (eps_value=1.8600000000000008, min_sample=40)
# 0.0513470891765093
# Processing combination 768/891 (eps_value=1.8600000000000008, min_sample=60)
# 0.03543323147758753
# Processing combination 769/891 (eps_value=1.8600000000000008, min_sample=80)
# 0.01991005304147021
# Processing combination 770/891 (eps_value=1.8600000000000008, min_sample=100)
# 0.005216067074369513
# Processing combination 771/891 (eps_value=1.8600000000000008, min_sample=120)
# -0.005145014598098245
# Processing combination 772/891 (eps_value=1.8600000000000008, min_sample=140)
# -0.015847532960911022
# Processing combination 773/891 (eps_value=1.8600000000000008, min_sample=160)
# -0.026047439092083572
# Processing combination 774/891 (eps_value=1.8600000000000008, min_sample=180)
# -0.03356133357398718
# Processing combination 775/891 (eps_value=1.8700000000000008, min_sample=20)
# 0.07166523055273841
# Processing combination 776/891 (eps_value=1.8700000000000008, min_sample=40)
# 0.05279121040832719
# Processing combination 777/891 (eps_value=1.8700000000000008, min_sample=60)
# 0.0372176431950458
# Processing combination 778/891 (eps_value=1.8700000000000008, min_sample=80)
# 0.021950505701396762
# Processing combination 779/891 (eps_value=1.8700000000000008, min_sample=100)
# 0.006613350577491998
# Processing combination 780/891 (eps_value=1.8700000000000008, min_sample=120)
# -0.004223461014798198
# Processing combination 781/891 (eps_value=1.8700000000000008, min_sample=140)
# -0.01500608278920972
# Processing combination 782/891 (eps_value=1.8700000000000008, min_sample=160)
# -0.024794727817941224
# Processing combination 783/891 (eps_value=1.8700000000000008, min_sample=180)
# -0.0322635849394131
# Processing combination 784/891 (eps_value=1.8800000000000008, min_sample=20)
# 0.07293498050660444
# Processing combination 785/891 (eps_value=1.8800000000000008, min_sample=40)
# 0.054199402244304064
# Processing combination 786/891 (eps_value=1.8800000000000008, min_sample=60)
# 0.03838062444317497
# Processing combination 787/891 (eps_value=1.8800000000000008, min_sample=80)
# 0.02405935651649758
# Processing combination 788/891 (eps_value=1.8800000000000008, min_sample=100)
# 0.008941571628857206
# Processing combination 789/891 (eps_value=1.8800000000000008, min_sample=120)
# -0.002894793321373809
# Processing combination 790/891 (eps_value=1.8800000000000008, min_sample=140)
# -0.014342336619610006
# Processing combination 791/891 (eps_value=1.8800000000000008, min_sample=160)
# -0.024476488779853908
# Processing combination 792/891 (eps_value=1.8800000000000008, min_sample=180)
# -0.03125308266379581
# Processing combination 793/891 (eps_value=1.8900000000000008, min_sample=20)
# 0.07447862063543305
# Processing combination 794/891 (eps_value=1.8900000000000008, min_sample=40)
# 0.05603201646780397
# Processing combination 795/891 (eps_value=1.8900000000000008, min_sample=60)
# 0.039894173992929806
# Processing combination 796/891 (eps_value=1.8900000000000008, min_sample=80)
# 0.025220263197026294
# Processing combination 797/891 (eps_value=1.8900000000000008, min_sample=100)
# 0.010461592700357717
# Processing combination 798/891 (eps_value=1.8900000000000008, min_sample=120)
# -0.0002151867138969237
# Processing combination 799/891 (eps_value=1.8900000000000008, min_sample=140)
# -0.01256885582001737
# Processing combination 800/891 (eps_value=1.8900000000000008, min_sample=160)
# -0.022832185492122205
# Processing combination 801/891 (eps_value=1.8900000000000008, min_sample=180)
# -0.029730135494418296
# Processing combination 802/891 (eps_value=1.9000000000000008, min_sample=20)
# 0.07578117457135071
# Processing combination 803/891 (eps_value=1.9000000000000008, min_sample=40)
# 0.05713656287927977
# Processing combination 804/891 (eps_value=1.9000000000000008, min_sample=60)
# 0.04105265774385719
# Processing combination 805/891 (eps_value=1.9000000000000008, min_sample=80)
# 0.027441848815526814
# Processing combination 806/891 (eps_value=1.9000000000000008, min_sample=100)
# 0.011936718897483635
# Processing combination 807/891 (eps_value=1.9000000000000008, min_sample=120)
# 0.0006184600159930666
# Processing combination 808/891 (eps_value=1.9000000000000008, min_sample=140)
# -0.011313193216857533
# Processing combination 809/891 (eps_value=1.9000000000000008, min_sample=160)
# -0.021088593780116384
# Processing combination 810/891 (eps_value=1.9000000000000008, min_sample=180)
# -0.029131502929767725
# Processing combination 811/891 (eps_value=1.9100000000000008, min_sample=20)
# 0.07775558342404804
# Processing combination 812/891 (eps_value=1.9100000000000008, min_sample=40)
# 0.058638558198147984
# Processing combination 813/891 (eps_value=1.9100000000000008, min_sample=60)
# 0.04387482358724057
# Processing combination 814/891 (eps_value=1.9100000000000008, min_sample=80)
# 0.0295694615797078
# Processing combination 815/891 (eps_value=1.9100000000000008, min_sample=100)
# 0.014370231147397062
# Processing combination 816/891 (eps_value=1.9100000000000008, min_sample=120)
# 0.002661937833963328
# Processing combination 817/891 (eps_value=1.9100000000000008, min_sample=140)
# -0.009610142270461763
# Processing combination 818/891 (eps_value=1.9100000000000008, min_sample=160)
# -0.019211270465041206
# Processing combination 819/891 (eps_value=1.9100000000000008, min_sample=180)
# -0.02789337847782011
# Processing combination 820/891 (eps_value=1.9200000000000008, min_sample=20)
# 0.07901970852779652
# Processing combination 821/891 (eps_value=1.9200000000000008, min_sample=40)
# 0.06048971797682915
# Processing combination 822/891 (eps_value=1.9200000000000008, min_sample=60)
# 0.04546089638824132
# Processing combination 823/891 (eps_value=1.9200000000000008, min_sample=80)
# 0.03187746413758595
# Processing combination 824/891 (eps_value=1.9200000000000008, min_sample=100)
# 0.0179307845800033
# Processing combination 825/891 (eps_value=1.9200000000000008, min_sample=120)
# 0.005588266359476915
# Processing combination 826/891 (eps_value=1.9200000000000008, min_sample=140)
# -0.006392096908831097
# Processing combination 827/891 (eps_value=1.9200000000000008, min_sample=160)
# -0.017374601556806098
# Processing combination 828/891 (eps_value=1.9200000000000008, min_sample=180)
# -0.02659506688153894
# Processing combination 829/891 (eps_value=1.9300000000000008, min_sample=20)
# 0.08074402425115795
# Processing combination 830/891 (eps_value=1.9300000000000008, min_sample=40)
# 0.06220806311393782
# Processing combination 831/891 (eps_value=1.9300000000000008, min_sample=60)
# 0.04742035393663913
# Processing combination 832/891 (eps_value=1.9300000000000008, min_sample=80)
# 0.03471272038850613
# Processing combination 833/891 (eps_value=1.9300000000000008, min_sample=100)
# 0.02106598220762976
# Processing combination 834/891 (eps_value=1.9300000000000008, min_sample=120)
# 0.008174226770972981
# Processing combination 835/891 (eps_value=1.9300000000000008, min_sample=140)
# -0.003408726327658159
# Processing combination 836/891 (eps_value=1.9300000000000008, min_sample=160)
# -0.015388207105084846
# Processing combination 837/891 (eps_value=1.9300000000000008, min_sample=180)
# -0.022883557594515533
# Processing combination 838/891 (eps_value=1.9400000000000008, min_sample=20)
# 0.08268409747114194
# Processing combination 839/891 (eps_value=1.9400000000000008, min_sample=40)
# 0.0647328544396516
# Processing combination 840/891 (eps_value=1.9400000000000008, min_sample=60)
# 0.05043772856572779
# Processing combination 841/891 (eps_value=1.9400000000000008, min_sample=80)
# 0.039133110893689114
# Processing combination 842/891 (eps_value=1.9400000000000008, min_sample=100)
# 0.026978905262980784
# Processing combination 843/891 (eps_value=1.9400000000000008, min_sample=120)
# 0.01278292011040914
# Processing combination 844/891 (eps_value=1.9400000000000008, min_sample=140)
# 0.0014476691372739229
# Processing combination 845/891 (eps_value=1.9400000000000008, min_sample=160)
# -0.009011542902625761
# Processing combination 846/891 (eps_value=1.9400000000000008, min_sample=180)
# -0.017207592515822157
# Processing combination 847/891 (eps_value=1.9500000000000008, min_sample=20)
# 0.08532856514113901
# Processing combination 848/891 (eps_value=1.9500000000000008, min_sample=40)
# 0.06793684967734487
# Processing combination 849/891 (eps_value=1.9500000000000008, min_sample=60)
# 0.05483382624435841
# Processing combination 850/891 (eps_value=1.9500000000000008, min_sample=80)
# 0.044218697885802453
# Processing combination 851/891 (eps_value=1.9500000000000008, min_sample=100)
# 0.03271120403787967
# Processing combination 852/891 (eps_value=1.9500000000000008, min_sample=120)
# 0.02113144776921725
# Processing combination 853/891 (eps_value=1.9500000000000008, min_sample=140)
# 0.009866433075060752
# Processing combination 854/891 (eps_value=1.9500000000000008, min_sample=160)
# 0.002823650121299783
# Processing combination 855/891 (eps_value=1.9500000000000008, min_sample=180)
# -0.008359041473552075
# Processing combination 856/891 (eps_value=1.9600000000000009, min_sample=20)
# 0.0873004640283636
# Processing combination 857/891 (eps_value=1.9600000000000009, min_sample=40)
# 0.0720779045892572
# Processing combination 858/891 (eps_value=1.9600000000000009, min_sample=60)
# 0.058869402309208015
# Processing combination 859/891 (eps_value=1.9600000000000009, min_sample=80)
# 0.04872343371462338
# Processing combination 860/891 (eps_value=1.9600000000000009, min_sample=100)
# 0.037603390093475283
# Processing combination 861/891 (eps_value=1.9600000000000009, min_sample=120)
# 0.028604975374150448
# Processing combination 862/891 (eps_value=1.9600000000000009, min_sample=140)
# 0.018472815889356932
# Processing combination 863/891 (eps_value=1.9600000000000009, min_sample=160)
# 0.011048220929157007
# Processing combination 864/891 (eps_value=1.9600000000000009, min_sample=180)
# 0.003203490405519502
# Processing combination 865/891 (eps_value=1.9700000000000009, min_sample=20)
# 0.08942229028720684
# Processing combination 866/891 (eps_value=1.9700000000000009, min_sample=40)
# 0.07461218931957274
# Processing combination 867/891 (eps_value=1.9700000000000009, min_sample=60)
# 0.06202397355646337
# Processing combination 868/891 (eps_value=1.9700000000000009, min_sample=80)
# 0.05209051076910746
# Processing combination 869/891 (eps_value=1.9700000000000009, min_sample=100)
# 0.04102708986859068
# Processing combination 870/891 (eps_value=1.9700000000000009, min_sample=120)
# 0.032610489246670635
# Processing combination 871/891 (eps_value=1.9700000000000009, min_sample=140)
# 0.023828585962568406
# Processing combination 872/891 (eps_value=1.9700000000000009, min_sample=160)
# 0.016939293839429923
# Processing combination 873/891 (eps_value=1.9700000000000009, min_sample=180)
# 0.010290988261233132
# Processing combination 874/891 (eps_value=1.9800000000000009, min_sample=20)
# 0.09268367476000713
# Processing combination 875/891 (eps_value=1.9800000000000009, min_sample=40)
# 0.07907834852224858
# Processing combination 876/891 (eps_value=1.9800000000000009, min_sample=60)
# 0.06668016809117587
# Processing combination 877/891 (eps_value=1.9800000000000009, min_sample=80)
# 0.057409009555373015
# Processing combination 878/891 (eps_value=1.9800000000000009, min_sample=100)
# 0.04841697855548976
# Processing combination 879/891 (eps_value=1.9800000000000009, min_sample=120)
# 0.03997648132114986
# Processing combination 880/891 (eps_value=1.9800000000000009, min_sample=140)
# 0.0330026483756306
# Processing combination 881/891 (eps_value=1.9800000000000009, min_sample=160)
# 0.024997856590222935
# Processing combination 882/891 (eps_value=1.9800000000000009, min_sample=180)
# 0.02073367793811676
# Processing combination 883/891 (eps_value=1.9900000000000009, min_sample=20)
# 0.09709368843682091
# Processing combination 884/891 (eps_value=1.9900000000000009, min_sample=40)
# 0.08485047934685921
# Processing combination 885/891 (eps_value=1.9900000000000009, min_sample=60)
# 0.07347608159703878
# Processing combination 886/891 (eps_value=1.9900000000000009, min_sample=80)
# 0.06369293323162506
# Processing combination 887/891 (eps_value=1.9900000000000009, min_sample=100)
# 0.0545442632611924
# Processing combination 888/891 (eps_value=1.9900000000000009, min_sample=120)
# 0.04769129231578487
# Processing combination 889/891 (eps_value=1.9900000000000009, min_sample=140)
# 0.0409264516868562
# Processing combination 890/891 (eps_value=1.9900000000000009, min_sample=160)
# 0.03471867208464809
# Processing combination 891/891 (eps_value=1.9900000000000009, min_sample=180)
# 0.027368087801056904

# %%
df_analysis_pca.query("n_clusters > 1").sort_values(by="score", ascending=False)
# Out:
#      eps_value  min_sample     score  n_clusters                 cluster_types
# 882       1.99          20  0.097094           2                       {0, -1}
# 873       1.98          20  0.092684           2                       {0, -1}
# 864       1.97          20  0.089422           2                       {0, -1}
# 855       1.96          20  0.087300           2                       {0, -1}
# 846       1.95          20  0.085329           2                       {0, -1}
# ..         ...         ...       ...         ...                           ...
# 126       1.15          20 -0.222201           8     {0, 1, 2, 3, 4, 5, 6, -1}
# 99        1.12          20 -0.222372           8     {0, 1, 2, 3, 4, 5, 6, -1}
# 90        1.11          20 -0.222372           8     {0, 1, 2, 3, 4, 5, 6, -1}
# 81        1.10          20 -0.222741           8     {0, 1, 2, 3, 4, 5, 6, -1}
# 261       1.30          20 -0.224984           9  {0, 1, 2, 3, 4, 5, 6, 7, -1}
#
# [462 rows x 5 columns]

# %% [markdown]
# Long story short, clustering does not yield good usage possiblities as it the high sillhouette scores are achieved with just one cluster in all cases.
